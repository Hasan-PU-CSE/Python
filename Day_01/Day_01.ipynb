# %%
print('Hello Bangladesh', end='/n')
# Out:
# Hello Bangladesh/n

# %%
var = 'Hasan'
print('My name is '+var)
# Out:
# My name is Hasan

# %% [markdown]
# Variable is a container to store data.

# %%
print('var')
# Out:
# var

# %%
id(var) #id = location
# Out:
# 1882360533024

# %%
import sys
sys.getsizeof(var)  #sys.getsizeof, find out memory space
# Out:
# 46

# %%
#variable declare
a = 2
A = 3
_hasan = 23

Hasan = "Good"
hasan = 'saima'
print(Hasan)
firstName = 'camel case'
MyNameIs = 'pascal case'
my_variable_name = 'snake case'
print(my_variable_name)
x = y = z = 'hasan' # one values muptiple variables
print(x)
# Out:
# Good
# snake case
# hasan

# %% [raw]
# x, y, z = 'hasan', 'saima', 'naz' #multiple variables
# print(x)

# %% [markdown]
# Global vs local

# %%
name = 'Hasan' #global
def myfunction():
    name = 'Saima' #local
    print(name)
myfunction()

print(name)
# Out:
# Saima
# Hasan

# %%
def myfunction():
    my_id = 6789
    print(my_id)
myfunction()

print(my_id)
# Out:
# 6789
# 12345

# %%
def myfunction():
    my_id = 6789
    print(my_id)
myfunction()

print(my_id)
# Out:
# 6789
# 12345
