# %% [markdown]
# input funcation

# %%
data = 'Hasan'

type(data)
# Out:
# str

# %%
data = input()
# Out:
#  My name is Hasan

# %%
type(data)
# Out:
# str

# %%
x = input()
y = input()
# Out:
#  25
#  24

# %%
x+y
# Out:
# '2524'

# %%
type(x)
# Out:
# str

# %%
x = int(x)
y = int(y)

# %%
x+y
# Out:
# 49

# %%
type(y)
# Out:
# int

# %%
x = int(input('Enter your value'))
# Out:
# Enter your value 10

# %% [markdown]
# Data type

# %%
name = 'Hasan Khan' #string data

len(name)
# Out:
# 10

# %%
import sys
sys.getsizeof(name)
# Out:
# 51

# %%
#count sub string

name.count('Hasan')
# Out:
# 1

# %%
name.count('Saima')
# Out:
# 0

# %%
sub = 'Khan'

name.count(sub)
# Out:
# 1

# %% [markdown]
# Python string methods

# %%
my_city_name = 'Jhalokathi Sadar'

my_city_name.find('Sadar') # find value of string
# Out:
# 11

# %%
my_city_name.find('a')
# Out:
# 2

# %%
my_city_name.find('p') # not exist
# Out:
# -1

# %%
my_city_name.find('i',4, 10,) #you can define range
# Out:
# 9

# %%
my_city_name.index('k') #index function
# Out:
# 5

# %%
my_city_name.index('e') # this is defernece find function and index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 my_city_name.index('e')
#
# ValueError: substring not found

# %%
my_city_name.lower() #Convert all char into lower case
# Out:
# 'jhalokathi sadar'

# %%
my_city_name.upper() #Convert all char into upper case
# Out:
# 'JHALOKATHI SADAR'

# %%
my_city_name.casefold() #lower case
# Out:
# 'jhalokathi sadar'

# %%
name = 'Nusrat Jahan SAIMA'
name.capitalize() #Convert only first char into upper case
# Out:
# 'Nusrat jahan saima'

# %%
name.swapcase()
# Out:
# 'nUSRAT jAHAN saima'

# %%
name.title()
# Out:
# 'Nusrat Jahan Saima'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.isdigit()
# Out:
# False

# %%
name.encode()
# Out:
# b'Nusrat Jahan SAIMA'

# %%
type(name.encode())
# Out:
# bytes

# %%
name.split()
# Out:
# ['Nusrat', 'Jahan', 'SAIMA']

# %%
name.split()[2]
# Out:
# 'SAIMA'

# %%
name.center(50)
# Out:
# '                Nusrat Jahan SAIMA                '

# %%
name.replace('SAIMA','Naz')
# Out:
# 'Nusrat Jahan Naz'

# %%
#formating

x = 10
y = 20
z = x*y 
print('I have {} taka'.format(z))
# Out:
# I have 200 taka
